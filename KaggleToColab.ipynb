# %% [markdown]
# <a href="https://colab.research.google.com/github/harnalashok/general/blob/master/KaggleToColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Last amended: 23rd Feb, 2021
#Myfolder: github/harnalashok/general
#Ref: https://medium.com/analytics-vidhya/how-to-fetch-kaggle-datasets-into-google-colab-ea682569851a
#     https://colab.research.google.com/drive/19SVdlmnn6yRXCvNnE8PT1vbXrA8FrBo_#scrollTo=7YT39tcFZV08
# Objective:
#           Download files from Kaggle into Colab

# %%
#1.0 Import libraries
import keras
keras.__version__
import numpy as np

# %% [markdown]
# ### Enabling Colab to access Kaggle
#
# During this  lab session, we will work with a small database of images with dogs and cats. The cats vs. dogs dataset that we will use isn't packaged with Keras. It was made available by Kaggle.com as part of a computer vision competition in late 2013, back when convnets weren't quite mainstream. It is possible to download the database from the Kaggle website.
#
#
# As we are working with colaboratory google notebooks, we are working with remote machines, and we need to place the database there. As this database in in Kaggle, we need to use its API to place the database in our remote machine. The first step we will do is to install kaggle command lines to proceed to download the dataset.

# %%
# 1.1
# !pip install kaggle

# %% [markdown]
# To use the Kaggle API, sign up for a Kaggle account at https://www.kaggle.com. Then go to the 'My Account' page of your user profile (https://www.kaggle.com/username/account In my case, it is: https://www.kaggle.com/harnalashok/account) and select the button <u>'Create New API Token'</u> right at the bottom of your account page. This will trigger the download of `kaggle.json`, a file containing your API credentials. The next step is to upload this API Token to the Google Colab. Run the following code snippet, and then you can browse which files you want to upload from your machine to Google Colab. Choose the downloaded json file having your API Token and this is how we will be able to use the Kaggle API in the remote machine.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 1.2 Next upload the downloaded Kaggle's json file
#     to Colab

from google.colab import files

# 1.3 This command will create a Browse button
#      to browse and select a file from your machine
uploaded = files.upload()

# 1.4 Parse the uploaded json file. Extract keys.
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-2242acdf-ca3c-456a-98b1-23934bce117a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2242acdf-ca3c-456a-98b1-23934bce117a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# User uploaded file "kaggle.json" with length 67 bytes

# %% [markdown]
# For your security, ensure that other users that may be using your Google Colab machine do not have read access to your credentials. You can do this by running the following the two next steps. First, we create a .kaggle directory:

# %%
# 2.0 Secure your kaggle.json file
# !mkdir $HOME/.kaggle

# %% [markdown]
# And then we run the following command to move to authentication token there:

# %%
# 2.1
# !mv kaggle.json $HOME/.kaggle/kaggle.json
# !chmod 600 $HOME/.kaggle/kaggle.json

# %% [markdown]
# ###Downloading data file from Kaggle into Colab

# %% [markdown]
# The following image shows how to get a Kaggle command to download your data.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 3.0 Click on the 'Copy API Command' in the above image.
#     Paste the command below and execute
#     Download of data from Kaggle will begin
! kaggle datasets download -d alxmamaev/flowers-recognition
# Out:
# ...
#  98% 443M/450M [00:03<00:00, 143MB/s]
# 100% 450M/450M [00:03<00:00, 125MB/s]

# %%
# 3.1 Check if the files have been downloaded
# !ls
# Out:
# flowers-recognition.zip  sample_data

# %%
#3.2 Unzip the Kaggle file and delete the zipped file
# !unzip \*.zip  && rm *.zip
# Then check
# !ls

# %%
############ I am Done ##############
