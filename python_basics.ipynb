# %% [markdown]
# <a href="https://colab.research.google.com/github/harnalashok/general/blob/master/python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# LAst amended: 22/06/2024

# %% [markdown]
# ## Tuples vs Lists

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Refer [python docs](https://docs.python.org/2/library/sets.html#set-objects)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
l = [1,3,4,2,7,9]
print(sorted(l))
print(min(l))
print(max(l))
print(sum(l))
print(l.count(3))
print(l.index(3))   # Index of 3
# Out:
# [1, 2, 3, 4, 7, 9]
# 1
# 9
# 26
# 1
# 1

# %%
t = (1,4,6,8,3)
print(sorted(t))
print(min(t))
print(max(t))
print(sum(t))
print(t.count(1))
print(t.index(6))
# Out:
# [1, 3, 4, 6, 8]
# 1
# 8
# 22
# 1
# 2

# %%
l.append([8,9])
l.extend([9,10])

# %%
l[1] = 90
l
# Out:
# [1, 90, 4, 2, 7, 9, [8, 9], [8, 9], [8, 9], 9.1, [8, 9], 9, 10]

# %%
l.reverse()
l
# Out:
# [1, 90, 4, 2, 7, 9, [8, 9], [8, 9], [8, 9], 9.1, [8, 9], 9, 10]

# %%
l.pop(3)
l
# Out:
# [1, 90, 4, 9, [8, 9], [8, 9], [8, 9], 9.1, [8, 9], 9, 10]

# %%
l.insert(3,5)  # Insert 5 at index 3
l
# Out:
# [1, 90, 4, 5, 9, [8, 9], [8, 9], [8, 9], 9.1, [8, 9], 9, 10]

# %%
l.remove(5)
l
# Out:
# [1, 90, 4, 9, [8, 9], [8, 9], [8, 9], 9.1, [8, 9], 9, 10]

# %%
l.clear()

# %%
l = [90,300,20,400]
l.sort()
l
# Out:
# [20, 90, 300, 400]

# %%
l = [1,2,3,]

# %%
any(l)
# Out:
# True

# %%
list3 = [0, 2, 4]
print(any(list3))
# Out:
# True

# %%
all(list3)
# Out:
# False

# %%
l = [1,1,2,3,3]
l.count(1)
# Out:
# 2

# %%
for i in l:
  print(i)
# Out:
# 1
# 1
# 2
# 3
# 3

# %%
t
# Out:
# (1, 4, 6, 8, 3)

# %%
for i in t:
  print(i * 2)
# Out:
# 2
# 8
# 12
# 16
# 6

# %%
[ i*2  for i in l]
# Out:
# [2, 2, 4, 6, 6]

# %%
( i*2  for i in l)
# Out:
# <generator object <genexpr> at 0x78c7a07644a0>
